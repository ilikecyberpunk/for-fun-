# %%
import tkinter as tk
from tkinter import messagebox

Root = tk.Tk()
Root.title("MovingCube made by ILikeCyberpunk(ILikeSf and ILikeSteampunk)")

canvas = tk.Canvas(Root, bg = "green")
canvas.grid(row = 0, column = 1)

frame1 = tk.LabelFrame(Root, text = "chosse diagram", padx=10, pady=10)
frame1.grid(row = 0, column = 0)

radio_var = tk.StringVar(value="Cube")
radio_cube = tk.Radiobutton(frame1, text = "Cube", variable=radio_var, value = "Cube")
radio_cube.grid(row = 0, column = 0)
radio_illuminatti = tk.Radiobutton(frame1 , text = "pyramid", variable=radio_var, value = "Pyramid")
radio_illuminatti.grid(row= 1, column = 0)



def choose():
    try:
        if radio_var.get() == "Cube":
            r = int(entry_length.get())
            points_of_cube = [
                #앞면
                [r,-r,-r], #1
                [r, -r, r], #2
                [r, r, r], #3
                [r, r, -r], #4
              
                #뒷면
                [-r,-r,r], #5
                [-r,r,r], #6
                [-r,r,-r], #7
                [-r,-r,-r] #8

            #   5----------6
            #  /|         /|
            # 2----------3 |
            # | |        | |
            # | 8--------|-7
            # |/         |/
            # 1----------4
            


            ]




            
    except Exception as e:
        messagebox.showerror("error", f"{e}")

label_length = tk.Label(frame1, text = "set size(length of lines)").grid(row = 2, column = 0)
entry_length = tk.Entry(frame1)
entry_length.grid(row = 2, column = 1)

button1 = tk.Button(frame1, text = "Choose", command = choose, font = ("Times New Roamn", 20, "bold"))
button1.grid(row = 3, column = 0)



Root.mainloop()
